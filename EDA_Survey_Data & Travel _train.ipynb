# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option("display.max_columns", None)

pd.set_option("display.max_rows", 200)

# %%
sns.set()
sns.set_palette(palette='deep')

# %%
df_survey_tr = pd.read_csv(r'C:\Users\User\OneDrive\Desktop\HACKATHON\Surveydata_train_(1).csv')

# %%
df_travel_tr = pd.read_csv(r'C:\Users\User\OneDrive\Desktop\HACKATHON\Traveldata_train_(1).csv')

# %%
df_survey_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       94379 non-null  int64
#  1   Overall_Experience       94379 non-null  int64
#  2   Seat_comfort             94318 non-null  object
#  3   Seat_Class               94379 non-null  object
#  4   Arrival_time_convenient  85449 non-null  object
#  5   Catering                 85638 non-null  object
#  6   Platform_location        94349 non-null  object
#  7   Onboardwifi_service      94349 non-null  object
#  8   Onboard_entertainment    94361 non-null  object
#  9   Online_support           94288 non-null  object
#  10  Onlinebooking_Ease       94306 non-null  object
#  11  Onboard_service          86778 non-null  object
#  12  Leg_room                 94289 non-null  object
#  13  Baggage_handling         94237 non-null  object
#  14  Checkin_service          94302 non-null  object
#  15  Cleanliness              94373 non-null  object
#  16  Online_boarding          94373 non-null  object
# dtypes: int64(2), object(15)
# memory usage: 12.2+ MB

# %%
df_travel_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      94379 non-null  int64
#  1   Gender                  94302 non-null  object
#  2   CustomerType            85428 non-null  object
#  3   Age                     94346 non-null  float64
#  4   TypeTravel              85153 non-null  object
#  5   Travel_Class            94379 non-null  object
#  6   Travel_Distance         94379 non-null  int64
#  7   DepartureDelay_in_Mins  94322 non-null  float64
#  8   ArrivalDelay_in_Mins    94022 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 6.5+ MB

# %%
df_survey_tr_c1 = df_survey_tr.copy()

# %%
df_travel_tr_c1 = df_travel_tr.copy()

# %%
object_df_sur = df_survey_tr.select_dtypes(include='object')

# %%
object_df_sur.columns
# Out:
# Index(['Seat_comfort', 'Seat_Class', 'Arrival_time_convenient', 'Catering',
#        'Platform_location', 'Onboardwifi_service', 'Onboard_entertainment',
#        'Online_support', 'Onlinebooking_Ease', 'Onboard_service', 'Leg_room',
#        'Baggage_handling', 'Checkin_service', 'Cleanliness',
#        'Online_boarding'],
#       dtype='object')

# %%
for column in object_df_sur.columns:
    print(object_df_sur[column].value_counts())
    print('--------------------------------------------')
# Out:
# acceptable          21158
# need improvement    20946
# good                20595
# poor                15185
# excellent           12971
# extremely poor       3463
# Name: Seat_comfort, dtype: int64
# --------------------------------------------
# Green Car    47435
# Ordinary     46944
# Name: Seat_Class, dtype: int64
# --------------------------------------------
# good                19574
# excellent           17684
# acceptable          15177
# need improvement    14990
# poor                13692
# extremely poor       4332
# Name: Arrival_time_convenient, dtype: int64
# --------------------------------------------
# acceptable          18468
# need improvement    17978
# good                17969
# poor                13858
# excellent           13455
# extremely poor       3910
# Name: Catering, dtype: int64
# --------------------------------------------
# manageable           24173
# Convinient           21912
# need improvement     17832
# Inconvinient         16449
# very convinient      13981
# very inconvinient        2
# Name: Platform_location, dtype: int64
# --------------------------------------------
# good                22835
# excellent           20968
# acceptable          20118
# need improvement    19596
# poor                10741
# extremely poor         91
# Name: Onboardwifi_service, dtype: int64
# --------------------------------------------
# good                30446
# excellent           21644
# acceptable          17560
# need improvement    13926
# poor                 8641
# extremely poor       2144
# Name: Onboard_entertainment, dtype: int64
# --------------------------------------------
# good                30016
# excellent           25894
# acceptable          15702
# need improvement    12508
# poor                10167
# extremely poor          1
# Name: Online_support, dtype: int64
# --------------------------------------------
# good                28909
# excellent           24744
# acceptable          16390
# need improvement    14479
# poor                 9768
# extremely poor         16
# Name: Onlinebooking_Ease, dtype: int64
# --------------------------------------------
# good                27265
# excellent           21272
# acceptable          18071
# need improvement    11390
# poor                 8776
# extremely poor          4
# Name: Onboard_service, dtype: int64
# --------------------------------------------
# good                28870
# excellent           24832
# acceptable          16384
# need improvement    15753
# poor                 8110
# extremely poor        340
# Name: Leg_room, dtype: int64
# --------------------------------------------
# good                34944
# excellent           26003
# acceptable          17767
# need improvement     9759
# poor                 5764
# Name: Baggage_handling, dtype: int64
# --------------------------------------------
# good                26502
# acceptable          25803
# excellent           19641
# need improvement    11218
# poor                11137
# extremely poor          1
# Name: Checkin_service, dtype: int64
# --------------------------------------------
# good                35427
# excellent           26053
# acceptable          17449
# need improvement     9806
# poor                 5633
# extremely poor          5
# Name: Cleanliness, dtype: int64
# --------------------------------------------
# good                25533
# acceptable          22475
# excellent           21742
# need improvement    13451
# poor                11160
# extremely poor         12
# Name: Online_boarding, dtype: int64
# --------------------------------------------

# %%
object_df_tra = df_travel_tr.select_dtypes(include='object')

# %%
object_df_tra.columns
# Out:
# Index(['Gender', 'CustomerType', 'TypeTravel', 'Travel_Class'], dtype='object')

# %%
for column in object_df_tra.columns:
    print(object_df_tra[column].value_counts())
    print('--------------------------------------------')
# Out:
# Female    47815
# Male      46487
# Name: Gender, dtype: int64
# --------------------------------------------
# Loyal Customer       69823
# disloyal Customer    15605
# Name: CustomerType, dtype: int64
# --------------------------------------------
# Business travel    58617
# Personal Travel    26536
# Name: TypeTravel, dtype: int64
# --------------------------------------------
# Eco         49342
# Business    45037
# Name: Travel_Class, dtype: int64
# --------------------------------------------

# %%
merged_df = pd.merge(df_survey_tr_c1, df_travel_tr_c1, on='ID')

# %%
merged_df_c1 = merged_df.copy()

# %%
merged_df_c1.isnull().sum()[merged_df_c1.isnull().sum()>0]
# Out:
# Seat_comfort                 61
# Arrival_time_convenient    8930
# Catering                   8741
# Platform_location            30
# Onboardwifi_service          30
# Onboard_entertainment        18
# Online_support               91
# Onlinebooking_Ease           73
# Onboard_service            7601
# Leg_room                     90
# Baggage_handling            142
# Checkin_service              77
# Cleanliness                   6
# Online_boarding               6
# Gender                       77
# CustomerType               8951
# Age                          33
# TypeTravel                 9226
# DepartureDelay_in_Mins       57
# ArrivalDelay_in_Mins        357
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

for col in merged_df_c1.columns:
    if merged_df_c1[col].isna().sum() > 0:
        imputer = SimpleImputer(strategy='most_frequent')
        merged_df_c1[col] = imputer.fit_transform(merged_df_c1[[col]])

# %%
merged_df_c1.isnull().sum()[merged_df_c1.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
# All the null values are either imputed or dropped

# %%
merged_df_c1.describe(include='all').T
# Out:
#                            count unique              top   freq         mean  \
# ID                       94379.0    NaN              NaN    NaN   98847190.0
# Overall_Experience       94379.0    NaN              NaN    NaN     0.546658
# Seat_comfort               94379      6       acceptable  21219          NaN
# Seat_Class                 94379      2        Green Car  47435          NaN
# Arrival_time_convenient    94379      6             good  28504          NaN
# Catering                   94379      6       acceptable  27209          NaN
# Platform_location          94379      6       manageable  24203          NaN
# Onboardwifi_service        94379      6             good  22865          NaN
# Onboard_entertainment      94379      6             good  30464          NaN
# Online_support             94379      6             good  30107          NaN
# Onlinebooking_Ease         94379      6             good  28982          NaN
# Onboard_service            94379      6             good  34866          NaN
# Leg_room                   94379      6             good  28960          NaN
# Baggage_handling           94379      5             good  35086          NaN
# Checkin_service            94379      6             good  26579          NaN
# Cleanliness                94379      6             good  35433          NaN
# Online_boarding            94379      6             good  25539          NaN
# Gender                     94379      2           Female  47892          NaN
# CustomerType               94379      2   Loyal Customer  78774          NaN
# Age                      94379.0    NaN              NaN    NaN      39.4195
# TypeTravel                 94379      2  Business travel  67843          NaN
# Travel_Class               94379      2              Eco  49342          NaN
# Travel_Distance          94379.0    NaN              NaN    NaN  1978.888185
# DepartureDelay_in_Mins   94379.0    NaN              NaN    NaN    14.638246
# ArrivalDelay_in_Mins     94379.0    NaN              NaN    NaN    14.948463
#
#                                   std         min         25%         50%  \
# ID                       27245.014865  98800001.0  98823595.5  98847190.0
# Overall_Experience           0.497821         0.0         0.0         1.0
# Seat_comfort                      NaN         NaN         NaN         NaN
# Seat_Class                        NaN         NaN         NaN         NaN
# Arrival_time_convenient           NaN         NaN         NaN         NaN
# Catering                          NaN         NaN         NaN         NaN
# Platform_location                 NaN         NaN         NaN         NaN
# Onboardwifi_service               NaN         NaN         NaN         NaN
# Onboard_entertainment             NaN         NaN         NaN         NaN
# Online_support                    NaN         NaN         NaN         NaN
# Onlinebooking_Ease                NaN         NaN         NaN         NaN
# Onboard_service                   NaN         NaN         NaN         NaN
# Leg_room                          NaN         NaN         NaN         NaN
# Baggage_handling                  NaN         NaN         NaN         NaN
# Checkin_service                   NaN         NaN         NaN         NaN
# Cleanliness                       NaN         NaN         NaN         NaN
# Online_boarding                   NaN         NaN         NaN         NaN
# Gender                            NaN         NaN         NaN         NaN
# CustomerType                      NaN         NaN         NaN         NaN
# Age                         15.113991         7.0        27.0        40.0
# TypeTravel                        NaN         NaN         NaN         NaN
# Travel_Class                      NaN         NaN         NaN         NaN
# Travel_Distance           1027.961019        50.0      1359.0      1923.0
# DepartureDelay_in_Mins      38.128961         0.0         0.0         0.0
# ArrivalDelay_in_Mins        38.377695         0.0         0.0         0.0
#
#                                 75%         max
# ID                       98870784.5  98894379.0
# Overall_Experience              1.0         1.0
# Seat_comfort                    NaN         NaN
# Seat_Class                      NaN         NaN
# Arrival_time_convenient         NaN         NaN
# Catering                        NaN         NaN
# Platform_location               NaN         NaN
# Onboardwifi_service             NaN         NaN
# Onboard_entertainment           NaN         NaN
# Online_support                  NaN         NaN
# Onlinebooking_Ease              NaN         NaN
# Onboard_service                 NaN         NaN
# Leg_room                        NaN         NaN
# Baggage_handling                NaN         NaN
# Checkin_service                 NaN         NaN
# Cleanliness                     NaN         NaN
# Online_boarding                 NaN         NaN
# Gender                          NaN         NaN
# CustomerType                    NaN         NaN
# Age                            51.0        85.0
# TypeTravel                      NaN         NaN
# Travel_Class                    NaN         NaN
# Travel_Distance              2538.0      6951.0
# DepartureDelay_in_Mins         12.0      1592.0
# ArrivalDelay_in_Mins           13.0      1584.0

# %%
sns.boxplot(data=merged_df_c1,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(data=merged_df_c1,x='Travel_Distance')
# Out:
# <Axes: xlabel='Travel_Distance'>

# %%
sns.boxplot(data=merged_df_c1,x='DepartureDelay_in_Mins')
# Out:
# <Axes: xlabel='DepartureDelay_in_Mins'>

# %%
sns.boxplot(data=merged_df_c1,x='ArrivalDelay_in_Mins')
# Out:
# <Axes: xlabel='ArrivalDelay_in_Mins'>

# %%
merged_df_c1.to_csv('merged_data_train.csv', index=False)

# %%
df_survey_tes = pd.read_csv(r'C:\Users\User\OneDrive\Desktop\HACKATHON\Surveydata_test.csv')

# %%
df_travel_tes = pd.read_csv(r'C:\Users\User\OneDrive\Desktop\HACKATHON\Traveldata_test.csv')

# %%
df_survey_tes_c1 = df_survey_tes.copy()

# %%
df_travel_tes_c1 = df_travel_tes.copy()

# %%
df_survey_tes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       35602 non-null  int64
#  1   Seat_comfort             35580 non-null  object
#  2   Seat_Class               35602 non-null  object
#  3   Arrival_time_convenient  32277 non-null  object
#  4   Catering                 32245 non-null  object
#  5   Platform_location        35590 non-null  object
#  6   Onboardwifi_service      35590 non-null  object
#  7   Onboard_entertainment    35594 non-null  object
#  8   Online_support           35576 non-null  object
#  9   Onlinebooking_Ease       35584 non-null  object
#  10  Onboard_service          32730 non-null  object
#  11  Leg_room                 35577 non-null  object
#  12  Baggage_handling         35562 non-null  object
#  13  Checkin_service          35580 non-null  object
#  14  Cleanliness              35600 non-null  object
#  15  Online_boarding          35600 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 4.3+ MB

# %%
df_travel_tes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      35602 non-null  int64
#  1   Gender                  35572 non-null  object
#  2   CustomerType            32219 non-null  object
#  3   Age                     35591 non-null  float64
#  4   TypeTravel              32154 non-null  object
#  5   Travel_Class            35602 non-null  object
#  6   Travel_Distance         35602 non-null  int64
#  7   DepartureDelay_in_Mins  35573 non-null  float64
#  8   ArrivalDelay_in_Mins    35479 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.4+ MB

# %%
df_survey_tes.isnull().sum()
# Out:
# ID                            0
# Seat_comfort                 22
# Seat_Class                    0
# Arrival_time_convenient    3325
# Catering                   3357
# Platform_location            12
# Onboardwifi_service          12
# Onboard_entertainment         8
# Online_support               26
# Onlinebooking_Ease           18
# Onboard_service            2872
# Leg_room                     25
# Baggage_handling             40
# Checkin_service              22
# Cleanliness                   2
# Online_boarding               2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

for col in df_survey_tes_c1.columns:
    if df_survey_tes_c1[col].isna().sum()>0:
        imputer = SimpleImputer(strategy='most_frequent')
        df_survey_tes_c1[col] = imputer.fit_transform(df_survey_tes_c1[[col]])

# %%
df_survey_tes_c1.isnull().sum()[df_survey_tes_c1.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df_travel_tes.isnull().sum()
# Out:
# ID                           0
# Gender                      30
# CustomerType              3383
# Age                         11
# TypeTravel                3448
# Travel_Class                 0
# Travel_Distance              0
# DepartureDelay_in_Mins      29
# ArrivalDelay_in_Mins       123
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

for col in df_travel_tes_c1.columns:
    if df_travel_tes_c1[col].isna().sum()>0:
        imputer = SimpleImputer(strategy='most_frequent')
        df_travel_tes_c1[col] = imputer.fit_transform(df_travel_tes_c1[[col]])

# %%
df_travel_tes_c1.isnull().sum()
# Out:
# ID                        0
# Gender                    0
# CustomerType              0
# Age                       0
# TypeTravel                0
# Travel_Class              0
# Travel_Distance           0
# DepartureDelay_in_Mins    0
# ArrivalDelay_in_Mins      0
# dtype: int64

# %%
merged_df_tes = pd.merge(df_survey_tes_c1, df_travel_tes_c1, on='ID')

# %%
merged_df_tes_c1 = merged_df_tes.copy()

# %%
merged_df_tes_c1.describe(include='all').T
# Out:
#                            count unique              top   freq         mean  \
# ID                       35602.0    NaN              NaN    NaN   99917801.5
# Seat_comfort               35602      6       acceptable   8025          NaN
# Seat_Class                 35602      2         Ordinary  17860          NaN
# Arrival_time_convenient    35602      6             good  10686          NaN
# Catering                   35602      6       acceptable  10490          NaN
# Platform_location          35602      5       manageable   9376          NaN
# Onboardwifi_service        35602      6             good   8755          NaN
# Onboard_entertainment      35602      6             good  11444          NaN
# Online_support             35602      5             good  11513          NaN
# Onlinebooking_Ease         35602      6             good  11043          NaN
# Onboard_service            35602      5             good  13094          NaN
# Leg_room                   35602      6             good  10867          NaN
# Baggage_handling           35602      5             good  13331          NaN
# Checkin_service            35602      5             good  10004          NaN
# Cleanliness                35602      5             good  13423          NaN
# Online_boarding            35602      6             good   9682          NaN
# Gender                     35602      2           Female  18099          NaN
# CustomerType               35602      2   Loyal Customer  29732          NaN
# Age                      35602.0    NaN              NaN    NaN    39.446857
# TypeTravel                 35602      2  Business travel  25761          NaN
# Travel_Class               35602      2              Eco  18473          NaN
# Travel_Distance          35602.0    NaN              NaN    NaN  1987.151761
# DepartureDelay_in_Mins   35602.0    NaN              NaN    NaN    14.868575
# ArrivalDelay_in_Mins     35602.0    NaN              NaN    NaN    15.255913
#
#                                   std         min          25%         50%  \
# ID                       10277.556478  99900001.0  99908901.25  99917801.5
# Seat_comfort                      NaN         NaN          NaN         NaN
# Seat_Class                        NaN         NaN          NaN         NaN
# Arrival_time_convenient           NaN         NaN          NaN         NaN
# Catering                          NaN         NaN          NaN         NaN
# Platform_location                 NaN         NaN          NaN         NaN
# Onboardwifi_service               NaN         NaN          NaN         NaN
# Onboard_entertainment             NaN         NaN          NaN         NaN
# Online_support                    NaN         NaN          NaN         NaN
# Onlinebooking_Ease                NaN         NaN          NaN         NaN
# Onboard_service                   NaN         NaN          NaN         NaN
# Leg_room                          NaN         NaN          NaN         NaN
# Baggage_handling                  NaN         NaN          NaN         NaN
# Checkin_service                   NaN         NaN          NaN         NaN
# Cleanliness                       NaN         NaN          NaN         NaN
# Online_boarding                   NaN         NaN          NaN         NaN
# Gender                            NaN         NaN          NaN         NaN
# CustomerType                      NaN         NaN          NaN         NaN
# Age                         15.135217         7.0         27.0        40.0
# TypeTravel                        NaN         NaN          NaN         NaN
# Travel_Class                      NaN         NaN          NaN         NaN
# Travel_Distance           1024.308863        50.0       1360.0      1929.0
# DepartureDelay_in_Mins      37.882395         0.0          0.0         0.0
# ArrivalDelay_in_Mins        38.475161         0.0          0.0         0.0
#
#                                  75%         max
# ID                       99926701.75  99935602.0
# Seat_comfort                     NaN         NaN
# Seat_Class                       NaN         NaN
# Arrival_time_convenient          NaN         NaN
# Catering                         NaN         NaN
# Platform_location                NaN         NaN
# Onboardwifi_service              NaN         NaN
# Onboard_entertainment            NaN         NaN
# Online_support                   NaN         NaN
# Onlinebooking_Ease               NaN         NaN
# Onboard_service                  NaN         NaN
# Leg_room                         NaN         NaN
# Baggage_handling                 NaN         NaN
# Checkin_service                  NaN         NaN
# Cleanliness                      NaN         NaN
# Online_boarding                  NaN         NaN
# Gender                           NaN         NaN
# CustomerType                     NaN         NaN
# Age                             51.0        85.0
# TypeTravel                       NaN         NaN
# Travel_Class                     NaN         NaN
# Travel_Distance               2559.0      6868.0
# DepartureDelay_in_Mins          13.0       978.0
# ArrivalDelay_in_Mins            13.0       970.0

# %%
merged_df_tes_c1.to_csv('merged_data_test.csv', index=False)
